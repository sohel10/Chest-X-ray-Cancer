# %%
import os

PROJECT_ROOT = r"C:/Users/sohel/Downloads/Ai_health/Chest-X-ray-Cancer"
os.chdir(PROJECT_ROOT)

print("Working directory:", os.getcwd())
# Out:
# Working directory: C:\Users\sohel\Downloads\Ai_health\Chest-X-ray-Cancer

# %%
from cnnClassifier.config.configuration import ConfigurationManager
from cnnClassifier.components.model_evaluation import Evaluation
# Out:
# c:\Users\sohel\miniconda3\envs\xray\lib\site-packages\mlflow\utils\requirements_utils.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
import os

print("Data ingestion folder:", os.listdir("artifacts/data_ingestion"))
print("Training folder:", os.listdir("artifacts/training"))
# Out:
# Data ingestion folder: ['data_ct', 'data_ct.zip']
# Training folder: ['model.h5']

# %%
import tensorflow as tf
from pathlib import Path

# %%
model = tf.keras.models.load_model("artifacts/training/model.h5")
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.30
)

valid_gen = datagen.flow_from_directory(
    "artifacts/data_ingestion/data_ct",
    subset="validation",
    shuffle=False,
    target_size=(224,224),
    batch_size=32
)
# Out:
# Found 102 images belonging to 2 classes.

# %%
loss, acc = model.evaluate(valid_gen)
print("Loss:", loss)
print("Accuracy:", acc)
# Out:
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0070 - accuracy: 0.9902
# Loss: 0.0069786738604307175
# Accuracy: 0.9901960492134094

# %%
import json

scores = {"loss": float(loss), "accuracy": float(acc)}

with open("scores.json", "w") as f:
    json.dump(scores, f, indent=4)

print("Scores saved!")
# Out:
# Scores saved!
